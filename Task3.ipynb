# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka302004/Task_1/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                                  OASIS
#                                INFOBYTE
#
#     PRIYANKA PAWAR
#     DATA SCIENCE INTERN,2024
#     TASK-3, SALES ANALYSIS

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Reading CSV File**

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 194         -1                95  volvo       gas        std         four
# 195         -1                95  volvo       gas      turbo         four
# 196         -1                95  volvo       gas        std         four
# 197         -1                95  volvo    diesel      turbo         four
# 198         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 194      sedan          rwd           front       109.1  ...          141
# 195      sedan          rwd           front       109.1  ...          141
# 196      sedan          rwd           front       109.1  ...          173
# 197      sedan          rwd           front       109.1  ...          145
# 198      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
df.shape
# Out:
# (199, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          199 non-null    int64
#  1   normalized-losses  199 non-null    object
#  2   make               199 non-null    object
#  3   fuel-type          199 non-null    object
#  4   aspiration         199 non-null    object
#  5   num-of-doors       199 non-null    object
#  6   body-style         199 non-null    object
#  7   drive-wheels       199 non-null    object
#  8   engine-location    199 non-null    object
#  9   wheel-base         199 non-null    float64
#  10  length             199 non-null    float64
#  11  width              199 non-null    float64
#  12  height             199 non-null    float64
#  13  curb-weight        199 non-null    int64
#  14  engine-type        199 non-null    object
#  15  num-of-cylinders   199 non-null    object
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  199.000000  199.000000  199.000000  199.000000  199.000000
# mean     0.788945   98.852764  174.099497   65.905528   53.816583
# std      1.220895    6.085940   12.489391    2.176300    2.395002
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   97.000000  173.200000   65.400000   54.100000
# 75%      2.000000  102.400000  183.500000   66.900000   55.550000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size        bore      stroke  compression-ratio  \
# count   199.000000   199.000000  199.000000  199.000000         199.000000
# mean   2558.829146   127.949749    3.328442    3.248945          10.171960
# std     528.005482    41.534670    0.274602    0.311583           4.027676
# ...

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 194         -1                95        volvo       gas        std
# 195         -1                95        volvo       gas      turbo
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo    diesel      turbo
# 198         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
x=df.iloc[:,0:-1]

# %%
x
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 194         -1                95        volvo       gas        std
# 195         -1                95        volvo       gas      turbo
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo    diesel      turbo
# 198         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 194    16845
# 195    19045
# 196    21485
# 197    22470
# 198    22625
# Name: price, Length: 199, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
x_train
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 116          1               154       plymouth       gas        std
# 138          0               102         subaru       gas        std
# 155          0                91         toyota       gas        std
# 82           1               125     mitsubishi       gas        std
# 159          1               168         toyota       gas        std
# ..         ...               ...            ...       ...        ...
# 58           0               115          mazda       gas        std
# 21           1               118          dodge       gas        std
# 49           0                 ?         jaguar       gas        std
# 64          -1                93  mercedes-benz    diesel      turbo
# 68           3               142  mercedes-benz       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
x_test
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 56           0               115          mazda       gas        std
# 37           0               106          honda       gas        std
# 67          -1                 ?  mercedes-benz       gas        std
# 79           3                 ?     mitsubishi       gas      turbo
# 80           3                 ?     mitsubishi       gas      turbo
# 157          1               168         toyota       gas        std
# 177          2               122     volkswagen       gas        std
# 10           2               192            bmw       gas        std
# 128          3               150           saab       gas        std
# 62           0                 ?          mazda    diesel        std
# 65           0                93  mercedes-benz    diesel      turbo
# 17           0                 ?            bmw       gas        std
# 133          2                83         subaru       gas        std
# ...

# %%
y_train
# Out:
# 116     6229
# 138     9233
# 155     8358
# 82      8189
# 159     9298
#        ...
# 58     10245
# 21      5572
# 49     36000
# 64     28248
# 68     35056
# Name: price, Length: 159, dtype: object

# %%
y_test
# Out:
# 56      8495
# 37      7895
# 67     34184
# 79     14869
# 80     14489
# 157     8058
# 177     7975
# 10     16430
# 128    15040
# 62     18344
# 65     28176
# 17     36880
# 133     7053
# 194    16845
# 146     6488
# 38      9095
# 172    16558
# 149     8778
# 93      7999
# 29     12964
# 0      13495
# 2      16500
# 122    32528
# 179     8195
# 95      8949
# 121    22018
# 184     9980
# 39      8845
# 66     31600
# 19      6295
# 11     16925
# 45         ?
# 41     12945
# 92      7499
# 167     8948
# 1      16500
# 57     10595
# 188    12940
# 151     7198
# 166    17669
# Name: price, dtype: object

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
import matplotlib.pyplot as plt
